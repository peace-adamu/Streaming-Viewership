# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('streaming_viewership_data.csv')

# %%
df.head(10)
# Out:
#                                 User_ID                            Session_ID  \
# 0  eb4f9229-74df-45f6-baac-cf19241b8b30  cb2142a7-0750-49ed-b8ac-a975fe1ff69a
# 1  661d4b59-4328-410a-901c-1e3b4c40c334  3bc0a662-b353-4015-8b0c-55ceb510d13a
# 2  dd3fe9e9-ea82-4891-ab93-8a47c80e3251  bd545b4a-9f54-4e87-b9f8-15ae20b44f22
# 3  a1b3365b-1d00-4ddf-bc43-02fc9c10c680  0441086d-c59e-478d-a496-5c5b995ecfdb
# 4  338d3f91-5f1c-4590-8803-324901826406  0295f01d-7f15-4799-856c-90c688697ef8
# 5  076b03f1-fd5b-4abe-b22e-cf3b4fdad381  ae95a7b7-6502-4da8-a6e5-9717b67c754a
# 6  91d4aa91-da98-4ced-851d-c5c0194c63c4  550c6267-4cb4-431f-b868-c834f468f9b7
# 7  e707ea19-8d7e-476e-9bf8-c379f01f79da  51522575-8d6c-4489-bb07-ad8391d484e1
# 8  063c3c57-ea7e-42d2-ba7c-f0d35896e2da  7e11bec1-7e50-4963-ab8d-f480c3634efc
# 9  b82ccd39-0040-4be9-a969-78b40d4c0c97  32b6968e-3da0-4663-9c47-66cf3ea2cad7
#
#    Device_ID  Video_ID  Duration_Watched (minutes)        Genre  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6214 entries, 0 to 6213
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     6214 non-null   object
#  1   Session_ID                  6214 non-null   object
#  2   Device_ID                   6214 non-null   int64
#  3   Video_ID                    6214 non-null   int64
#  4   Duration_Watched (minutes)  6214 non-null   float64
#  5   Genre                       6214 non-null   object
#  6   Country                     6214 non-null   object
#  7   Age                         6214 non-null   int64
#  8   Gender                      6214 non-null   object
#  9   Subscription_Status         6214 non-null   object
#  10  Ratings                     6214 non-null   int64
#  11  Languages                   6214 non-null   object
#  12  Device_Type                 6214 non-null   object
# ...

# %%
df.describe()
# Out:
#          Device_ID     Video_ID  Duration_Watched (minutes)          Age  \
# count  6214.000000  6214.000000                 6214.000000  6214.000000
# mean    496.762150    50.323785                   60.378389    39.665594
# std     287.681163    28.671178                   34.597273    17.571317
# min       1.000000     1.000000                    0.055809    10.000000
# 25%     248.000000    26.000000                   30.413538    24.000000
# 50%     493.500000    50.000000                   60.765637    40.000000
# 75%     742.000000    75.000000                   90.874141    55.000000
# max    1000.000000   100.000000                  119.999972    70.000000
#
#            Ratings  Interaction_Events
# count  6214.000000         6214.000000
# mean      2.987448           50.776794
# std       1.403304           29.009363
# min       1.000000            0.000000
# 25%       2.000000           26.000000
# 50%       3.000000           51.000000
# ...

# %%
df.describe(include='all')
# Out:
#                                      User_ID  \
# count                                   6214
# unique                                  6214
# top     eb4f9229-74df-45f6-baac-cf19241b8b30
# freq                                       1
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# 25%                                      NaN
# 50%                                      NaN
# 75%                                      NaN
# max                                      NaN
#
#                                   Session_ID    Device_ID     Video_ID  \
# count                                   6214  6214.000000  6214.000000
# unique                                  6214          NaN          NaN
# top     cb2142a7-0750-49ed-b8ac-a975fe1ff69a          NaN          NaN
# freq                                       1          NaN          NaN
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Session_ID                    0
# Device_ID                     0
# Video_ID                      0
# Duration_Watched (minutes)    0
# Genre                         0
# Country                       0
# Age                           0
# Gender                        0
# Subscription_Status           0
# Ratings                       0
# Languages                     0
# Device_Type                   0
# Location                      0
# Playback_Quality              0
# Interaction_Events            0
# dtype: int64

# %%
df.keys()
# Out:
# Index(['User_ID', 'Session_ID', 'Device_ID', 'Video_ID',
#        'Duration_Watched (minutes)', 'Genre', 'Country', 'Age', 'Gender',
#        'Subscription_Status', 'Ratings', 'Languages', 'Device_Type',
#        'Location', 'Playback_Quality', 'Interaction_Events'],
#       dtype='object')

# %%
# checking for the value count in Age
df['Age'].value_counts()
# Out:
# Age
# 51    123
# 28    123
# 23    122
# 40    116
# 11    115
#      ...
# 29     86
# 55     84
# 14     84
# 69     82
# 34     79
# Name: count, Length: 61, dtype: int64

# %%
# from the value count of play back quality we can find out all quality lies btw 2000
df['Playback_Quality'].value_counts()
# Out:
# Playback_Quality
# 4K    2092
# SD    2066
# HD    2056
# Name: count, dtype: int64

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
sns.pairplot(df)

# %%
sns.set_style('whitegrid')
sns.countplot(x='Genre', data=df, palette='RdBu_r')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12796\3935403094.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Genre', data=df, palette='RdBu_r')
# <Axes: xlabel='Genre', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='Playback_Quality', hue='Device_Type', data=df, palette='rainbow')
# Out:
# <Axes: xlabel='Playback_Quality', ylabel='count'>

# %%
sns.distplot(df['Age'], kde=False, color='darkred', bins=50)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12796\3748354813.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], kde=False, color='darkred', bins=50)
# <Axes: xlabel='Age'>

# %%
sns.distplot(df['Duration_Watched (minutes)'], kde=False, bins=25, color='green')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9656\1499104525.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Duration_Watched (minutes)'], kde=False, bins=25, color='green')
# <Axes: xlabel='Duration_Watched (minutes)'>

# %%
df['Interaction_Events'].hist(bins=30, color='darkred', alpha=1)
# Out:
# <Axes: >

# %%
df['Interaction_Events'].hist(bins=30, color='darkred')
# Out:
# <Axes: >

# %%
sns.countplot(x='Country', data=df, alpha=1)
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
sns.countplot(x='Genre', data=df, alpha=1)
# Out:
# <Axes: xlabel='Genre', ylabel='count'>

# %%
# A graph showing the three different playback_quality
df['Playback_Quality'].value_counts()
df['Playback_Quality'].value_counts().plot(kind='bar')
plt.title('playback quality plot')
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]), [Text(0, 0, '4K'), Text(1, 0, 'SD'), Text(2, 0, 'HD')])

# %% [markdown]
# ### graph of playback quality
# ### All the three qualities lies between 2000

# %%
df['Ratings'].hist(color='yellow', bins=30, figsize=(8,6))
# Out:
# <Axes: >

# %%
#!pip install cufflinks==0.17.3

# %%
#!pip install plotly

# %%
import plotly
import plotly.express as px

# %%
#fig = px.bar(df, x='Genre', y='Device_Type')
#fig.show()

# %%
#!pip install nbformat
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000285BDF25100>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/nbformat/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000285BDF25400>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/nbformat/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000285BDF25700>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/nbformat/
# ...

# %%
# A pie chart showing the different percentage of the Genre, obviously Documentry has the highest
df['Genre'].value_counts().plot(kind='pie', autopct='%0.3f%%')
plt.title('pie chart of Genre')
# Out:
# Text(0.5, 1.0, 'pie chart of Genre')

# %% [markdown]
# ## A pie chart showing the different percentage of the Genre, obviously Documentry has the highest percentage of 17.139% which is in relation to the age range and type of device used

# %%
# A pie chart showing the different languages, English being the highest
df['Languages'].value_counts().plot(kind='pie', autopct='%0.2f%%')
plt.title('piechart of the different languages')
# Out:
# Text(0.5, 1.0, 'piechart of the different languages')

# %% [markdown]
# # A pie chart showing the different languages, English being the highest
# df['Languages'].value_counts().plot(kind='pie', autopct='%0.2f%%')
# plt.title('piechart of the different languages')

# %%
df['Device_Type'].value_counts().plot(kind='pie', autopct='%0.1f%%')
plt.title('piechart of the different device type');

# %% [markdown]
# ## A pie chart of different devices used smart TV has the highest frequency this could be as a result of the age range from the mode as 51 older people  watch ?

# %%
# Histogram plot showing the three diff playback_quality from the graph no clearity which is the hihest
plt.figure(figsize=(8,5))
plt.hist(df['Playback_Quality']);
plt.title('barchart of the three playback quality');

# %% [markdown]
# ## Histogram plot showing the three diff playback_quality

# %%
# Displot of the Age;the Ages start from 10 and ends at 70
sns.distplot(df['Age'])
plt.title('Distplot of AGE');
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_17012\3841571262.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# ## Displot of the Age;the Ages start from 10 and ends at 70

# %%
# A graph comparing Gender in respect to the diff Languages; female has been the highest in all languages except.figure(figsize=(8,6))
sns.countplot(data=df, x='Languages', hue='Gender')
plt.title('bivariate plot of language and gender');

# %% [markdown]
# ## graph comparing Gender in respect to the diff Languages; female has been the highest in all languages except in french

# %%
# A plot comparing the Gender in respect to the diff Ratings; Female has the highest populating in each rating except Rating 1(conclusion female likes anything) 
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Ratings', hue='Gender')
plt.title('bivariate plot of ratings and gender');

# %% [markdown]
# ## A plot comparing the Gender in respect to the diff Ratings; Female has the highest population in each rating except Rating 1(conclusion female likes anything)

# %%
#To  check if the device Type is affecting the ratings;i can draw a conclusion that tablet and laptop has equal rating 
sns.countplot(data=df, x='Ratings', hue='Device_Type')
plt.title('bivariate plot of ratings and device type');

# %% [markdown]
# ## A graph showing the rating in respond to the device type.
# ## smart TV has the highest percenntage in ccomparism to other device, from the ratiing of all device types smart is the best

# %%
#To check if the device type is affecting  the playback quality
sns.countplot(data=df, x='Device_Type', hue='Playback_Quality')
plt.title('bivariate plot of device type and playback quality');

# %% [markdown]
# ## a graph of device type and the playback quality
# ## 4k has the highest quality and smart TV has the best device has 4k to be the higehst, from this conclusion can be made that  because of the playback quality and the rating smart TV was the best in viewing  than other device

# %%
#A graph comparing playback_quality and Rating
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Ratings', hue='Playback_Quality')
plt.title('bivariate plot of rating and playback quality');

# %% [markdown]
# ## graph of playback quality in respect to rating

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
#A graphing the gender and genre;male watching documentry 
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Genre', hue='Gender')
plt.title('bivariate plot of genre and gender');

# %% [markdown]
# ## graph of gender and genre;male watching documentry

# %%
#A graph showing the highest device type and the gender 
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Device_Type', hue='Gender')
plt.title('bivariate plot of device type and gender');

# %% [markdown]
# ## graph compeling the relationship of genger with the device type, in conclusion both male and female goes for smart TV therefore it can be liken that almost all homes have smart TV to view

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Languages', hue='Playback_Quality')
plt.title('bivariate plot of languages and playback quality');

# %% [markdown]
# ## graph of playback quality and languages
# ## in conclusion 4k is recommended as the highest playback quality which align with  English language  watched

# %%
# a graph showing each language with the specific device type they go for

plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Languages', hue='Device_Type')
plt.title('bivariate plot of languages and device type');

# %% [markdown]
# ## graph of language in regards to device type

# %%
# a plot showing each language with their levels of genre they go for 
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Languages', hue='Genre')
plt.title('bivariate plot of language and genre');

# %% [markdown]
# ## grap of genre  with languages used
# ## English is mostly used to view documentary

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Genre', hue='Languages')
plt.title('bivariate plot of genre and languages');

# %%
# a graph showing subscription status in respect to the gender that goes forthem; in conclusion female likes free things
sns.countplot(data=df, x='Subscription_Status', hue='Gender')
plt.title('bivariate plot of subscription_status and gender');

# %% [markdown]
# ## graph of subscription status in relationship with gender
# ## female goes for free subsscripture

# %%
sns.countplot(data=df, x='Playback_Quality', hue='Subscription_Status')
# Out:
# <Axes: xlabel='Playback_Quality', ylabel='count'>

# %% [markdown]
# ## Graph of playback quality  in relation to the subscription status
# ## in conclusion 4k is the best which require premium subscription than others.

# %%
sns.countplot(data=df, x='Ratings', hue='Subscription_Status')
plt.title('bivariate plot of ratings and subscription_status');

# %% [markdown]
# ## Graph of  Subscription_Status in relation to  the  ratings
# ## in conclusion  the best rating is 5  and it is given as free subscription.

# %%
sns.countplot(data=df, x='Genre', hue='Subscription_Status')
plt.title('bivariate plot of genre and subscription_status');

# %% [markdown]
# ## Graph of Genre in relation to Subscription_Status
# ##  in conclusion because documentary is free thats why people goes for it more

# %%
sns.violinplot(data=df, x='Interaction_Events')
plt.title('violinplot of interaction_events');

# %%
sns.boxplot(df['Interaction_Events'])
plt.title('boxplot of interaction_events');

# %%
sns.scatterplot(data=df, y='Duration_Watched (minutes)', x='Gender')
plt.title('bivariate plot of duration_watched and gender');

# %% [markdown]
# ## graph of gender  in relation to duration watched
# ## both female  and male obviously spend the same time

# %%
sns.scatterplot(data=df, y='Duration_Watched (minutes)', x='Subscription_Status')
# Out:
# <Axes: xlabel='Subscription_Status', ylabel='Duration_Watched (minutes)'>

# %% [markdown]
# ## graph of  Subscription_Status  annd  duration watched
# ## both premium and free were watched at the same duration
